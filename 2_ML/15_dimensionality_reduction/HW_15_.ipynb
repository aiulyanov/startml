# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# ### Загрузим уже обработанные в прошлом ДЗ данные!

# %%
df = pd.read_csv('processed_sigma.csv')
df = df.drop("Trip_ID", axis=1)

X = df.drop("Surge_Pricing_Type", axis=1)
y = df["Surge_Pricing_Type"]

# %%
y.value_counts()
# Out:
# 2    56728
# 3    47720
# 1    27214
# Name: Surge_Pricing_Type, dtype: int64

# %% [markdown]
# ### Principal component analysis (PCA)

# %% [markdown]
# **Задание 1.** Спроецируйте данные на двумерную плоскость, используя `PCA`. Другими словами, выделите первые две главные компоненты и изобразите данные в осях этих компонент. Не забудьте центрировать признаки перед применением метода.
#
# **Какую долю изначальной дисперсии (информации) содержат/объясняют в себе обе компоненты?** Для этого воспользуйтесь атрибутом `explained_variance_ratio_` у PCA-класса.

# %%
### Центрируем данные

### Your code is here

X_centered = X - X.mean()

# %%
from sklearn.decomposition import PCA

### Your code is here
pca = PCA(n_components=2)

pca_df = pca.fit_transform(X_centered)
pca_df = pd.DataFrame(pca_df, columns=['PCA_1', 'PCA_2'])
pca_df.head()
# Out:
#        PCA_1      PCA_2
# 0 -38.743132 -23.282634
# 1 -13.209252 -25.023815
# 2  -2.004910  -1.637085
# 3  17.178458  -0.907657
# 4  14.477389 -11.656752

# %%
PCA_dataset = np.concatenate((pca_df.values, y.values.reshape(-1, 1)),
                              axis=1)
PCA_dataset = pd.DataFrame(PCA_dataset, columns=['PCA_1', 'PCA_2', 'Surge_Pricing_Type'])

# %%
import seaborn as sns

fig = plt.figure()
fig.set_size_inches(16, 10)
    
sns.scatterplot(data=PCA_dataset, x="PCA_1", y="PCA_2", hue='Surge_Pricing_Type')
# Out:
# <Axes: xlabel='PCA_1', ylabel='PCA_2'>

# %%
pca.explained_variance_ratio_
# Out:
# array([0.63176117, 0.21129863])

# %% [markdown]
# **Задание 2.** Изобразите heatmap корреляции изначальных признаков с новыми двумя главными компонентами. \
# **Какие признаки коррелируют с первой компонентой? Какие со второй? В качестве порогового значения договоримся о корреляции >= 0.5 по абсолютному значению **

# %%
### Your code is here
first_component_corr = X.corrwith(PCA_dataset.PCA_1)
second_component_corr = X.corrwith(PCA_dataset.PCA_2)


corrs = pd.concat((first_component_corr, second_component_corr),
                  axis=1)

corrs.columns = ['PCA_1', 'PCA_2']

corrs
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#                                   PCA_1     PCA_2
# Trip_Distance                  0.997767  0.018410
# Customer_Since_Months          0.121591  0.003500
# Life_Style_Index               0.480658 -0.025901
# Customer_Rating               -0.070104 -0.003757
# Cancellation_Last_1Month       0.000803  0.008960
# Var1                          -0.048532  0.998600
# Var2                           0.247178 -0.028448
# Var3                           0.293819 -0.026583
# Type_of_Cab_B                 -0.048751  0.005723
# Type_of_Cab_C                 -0.012059 -0.003397
# Type_of_Cab_D                  0.030079 -0.003183
# Type_of_Cab_E                  0.069302  0.000254
# Confidence_Life_Style_Index_B  0.227304  0.021109
# Confidence_Life_Style_Index_C  0.057982 -0.004819
# Destination_Type_B             0.027569  0.003273
# Destination_Type_C            -0.010905 -0.006302
# Destination_Type_D            -0.132203 -0.003049
# Destination_Type_E            -0.070717 -0.003479
# Destination_Type_F             0.008832 -0.005805
# Destination_Type_G            -0.079850  0.000093
# Destination_Type_H            -0.064851 -0.004513
# Destination_Type_I            -0.067626 -0.002996
# Destination_Type_J            -0.070659 -0.000492
# Destination_Type_K            -0.033570  0.001483
# Destination_Type_L             0.005635  0.003158
# Destination_Type_M            -0.009987  0.000549
# Destination_Type_N            -0.027875 -0.006745
# Gender_Male                    0.002366  0.000670

# %%
fig = plt.figure()

fig.set_size_inches(16, 10)

sns.heatmap(corrs, 
            xticklabels=corrs.columns,
            yticklabels=corrs.index,
            cmap='BrBG',
            vmin=-1,
            vmax=1)

plt.show()

# %%
corrs[(np.abs(corrs['PCA_1']) >= 0.5) | (np.abs(corrs['PCA_2']) >= 0.5)]
# Out:
#                   PCA_1    PCA_2
# Trip_Distance  0.997767  0.01841
# Var1          -0.048532  0.99860

# %% [markdown]
# **Задание 3.** Изобразите двумерную проекцию данных с метками классов. Выделите третью главную компоненту и аналогично нарисуйте трехмерную проекцию с метками классов. \
# **Какие признаки коррелируют с третьей компонентой?**

# %%
### Your code is here

pca_3d = PCA(n_components=3)

pca_3d.fit(X)

PCA_dataset_3d = pca_3d.transform(X)

PCA_dataset_3d = pd.DataFrame(PCA_dataset_3d, columns=['PCA_1', 'PCA_2', 'PCA_3'])

PCA_dataset_3d.head()
# Out:
#        PCA_1      PCA_2      PCA_3
# 0 -38.743132 -23.282634 -11.303274
# 1 -13.209252 -25.023815   5.664106
# 2  -2.004910  -1.637085   3.663032
# 3  17.178458  -0.907657  -3.191676
# 4  14.477389 -11.656752  22.999348

# %%
first_component_corr_3d = X.corrwith(PCA_dataset_3d.PCA_1)
second_component_corr_3d = X.corrwith(PCA_dataset_3d.PCA_2)
third_component_corr_3d = X.corrwith(PCA_dataset_3d.PCA_3)

corrs_3d = pd.concat((first_component_corr_3d, 
                      second_component_corr_3d, 
                      third_component_corr_3d), axis=1)

corrs_3d.columns = ['PCA_1', 'PCA_2', 'PCA_3']

corrs_3d
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#                                   PCA_1     PCA_2     PCA_3
# Trip_Distance                  0.997767  0.018410 -0.064176
# Customer_Since_Months          0.121591  0.003500  0.081370
# Life_Style_Index               0.480658 -0.025901  0.166688
# Customer_Rating               -0.070104 -0.003757 -0.236793
# Cancellation_Last_1Month       0.000803  0.008960  0.136222
# Var1                          -0.048532  0.998600  0.021003
# Var2                           0.247178 -0.028448  0.705159
# Var3                           0.293819 -0.026583  0.951081
# Type_of_Cab_B                 -0.048751  0.005723  0.011211
# Type_of_Cab_C                 -0.012059 -0.003397 -0.008707
# Type_of_Cab_D                  0.030079 -0.003183 -0.019453
# Type_of_Cab_E                  0.069302  0.000254 -0.024079
# Confidence_Life_Style_Index_B  0.227304  0.021109 -0.000882
# Confidence_Life_Style_Index_C  0.057982 -0.004819 -0.008557
# Destination_Type_B             0.027569  0.003273 -0.003024
# Destination_Type_C            -0.010905 -0.006302  0.013828
# Destination_Type_D            -0.132203 -0.003049 -0.016059
# Destination_Type_E            -0.070717 -0.003479 -0.018844
# Destination_Type_F             0.008832 -0.005805 -0.031646
# Destination_Type_G            -0.079850  0.000093 -0.013557
# Destination_Type_H            -0.064851 -0.004513  0.010386
# Destination_Type_I            -0.067626 -0.002996 -0.006967
# Destination_Type_J            -0.070659 -0.000492  0.003865
# Destination_Type_K            -0.033570  0.001483 -0.019527
# Destination_Type_L             0.005635  0.003158 -0.011154
# Destination_Type_M            -0.009987  0.000549 -0.001850
# Destination_Type_N            -0.027875 -0.006745 -0.008892
# Gender_Male                    0.002366  0.000670  0.003067

# %% [markdown]
# Советуем еще и замерить попарные корреляции между главными компонентами! Это поможет в ответе на один из тестовых вопросов.

# %%
### Your code is here

cm = corrs_3d.corr()

print(cm)
# Out:
#           PCA_1     PCA_2     PCA_3
# PCA_1  1.000000 -0.096645  0.278461
# PCA_2 -0.096645  1.000000 -0.068845
# PCA_3  0.278461 -0.068845  1.000000

# %%
cmx = X.corr()
print(cmx)
# Out:
#                                Trip_Distance  Customer_Since_Months  \
# Trip_Distance                       1.000000               0.114413
# Customer_Since_Months               0.114413               1.000000
# Life_Style_Index                    0.468332               0.119279
# Customer_Rating                    -0.054654              -0.048969
# Cancellation_Last_1Month           -0.007686              -0.006180
# Var1                               -0.031388              -0.000977
# Var2                                0.200456               0.041814
# Var3                                0.231706               0.110851
# Type_of_Cab_B                      -0.049238              -0.002355
# Type_of_Cab_C                      -0.011554               0.004740
# Type_of_Cab_D                       0.031177               0.005189
# Type_of_Cab_E                       0.070691               0.002740
# Confidence_Life_Style_Index_B       0.227132               0.058714
# Confidence_Life_Style_Index_C       0.058356              -0.003349
# Destination_Type_B                  0.027752              -0.010592
# Destination_Type_C                 -0.011911               0.035630
# Destination_Type_D                 -0.130917              -0.012894
# Destination_Type_E                 -0.069371              -0.024754
# Destination_Type_F                  0.010783              -0.020596
# Destination_Type_G                 -0.078761              -0.023704
# Destination_Type_H                 -0.065450              -0.005812
# Destination_Type_I                 -0.067025              -0.038896
# Destination_Type_J                 -0.070772               0.001861
# Destination_Type_K                 -0.032169              -0.033298
# Destination_Type_L                  0.006428              -0.011319
# Destination_Type_M                 -0.009844               0.001978
# Destination_Type_N                 -0.027335              -0.021416
# Gender_Male                         0.002173               0.001326
#
#                                Life_Style_Index  Customer_Rating  \
# Trip_Distance                          0.468332        -0.054654
# Customer_Since_Months                  0.119279        -0.048969
# Life_Style_Index                       1.000000         0.189165
# Customer_Rating                        0.189165         1.000000
# Cancellation_Last_1Month               0.068188         0.003595
# Var1                                  -0.045710        -0.005398
# Var2                                   0.215944        -0.302968
# Var3                                   0.303324        -0.227531
# Type_of_Cab_B                         -0.002509         0.027020
# Type_of_Cab_C                         -0.033352        -0.031793
# Type_of_Cab_D                         -0.024123        -0.051427
# Type_of_Cab_E                          0.000149        -0.036243
# Confidence_Life_Style_Index_B          0.068243        -0.076343
# Confidence_Life_Style_Index_C          0.060389        -0.007974
# Destination_Type_B                    -0.003996        -0.022255
# Destination_Type_C                     0.069772         0.086033
# Destination_Type_D                    -0.044660         0.045192
# Destination_Type_E                    -0.007653         0.065998
# Destination_Type_F                     0.021958         0.055861
# Destination_Type_G                    -0.027208         0.058156
# Destination_Type_H                    -0.008661         0.012988
# Destination_Type_I                    -0.018124         0.022421
# Destination_Type_J                    -0.015995         0.012134
# Destination_Type_K                    -0.006097         0.027700
# Destination_Type_L                     0.003144         0.033101
# Destination_Type_M                     0.008153         0.010281
# Destination_Type_N                    -0.026124         0.018762
# Gender_Male                            0.000626         0.000468
#
#                                Cancellation_Last_1Month      Var1      Var2  \
# Trip_Distance                                 -0.007686 -0.031388  0.200456
# Customer_Since_Months                         -0.006180 -0.000977  0.041814
# Life_Style_Index                               0.068188 -0.045710  0.215944
# Customer_Rating                                0.003595 -0.005398 -0.302968
# Cancellation_Last_1Month                       1.000000  0.011711  0.095830
# Var1                                           0.011711  1.000000 -0.025133
# Var2                                           0.095830 -0.025133  1.000000
# Var3                                           0.128686 -0.020892  0.683437
# Type_of_Cab_B                                 -0.051113  0.008309 -0.007217
# Type_of_Cab_C                                  0.026167 -0.002987 -0.005590
# Type_of_Cab_D                                  0.054030 -0.005039  0.003931
# Type_of_Cab_E                                  0.049120 -0.003617  0.002091
# Confidence_Life_Style_Index_B                  0.051301  0.009982  0.042808
# Confidence_Life_Style_Index_C                 -0.005575 -0.007783  0.012706
# Destination_Type_B                            -0.041103  0.001896  0.029963
# Destination_Type_C                             0.050529 -0.005515 -0.026919
# Destination_Type_D                             0.009222  0.003019 -0.059479
# Destination_Type_E                             0.017663 -0.000446 -0.043096
# Destination_Type_F                             0.028450 -0.006899 -0.032692
# Destination_Type_G                             0.004040  0.003675 -0.042712
# Destination_Type_H                             0.002679 -0.001149 -0.016374
# Destination_Type_I                             0.007901  0.000149 -0.024090
# Destination_Type_J                             0.002417  0.003012 -0.020074
# Destination_Type_K                             0.011404  0.002711 -0.017317
# Destination_Type_L                             0.037134  0.002638 -0.015042
# Destination_Type_M                             0.003636  0.000995 -0.002572
# Destination_Type_N                             0.004370 -0.005564 -0.011555
# Gender_Male                                    0.002307  0.000619  0.003183
#
#                                    Var3  Type_of_Cab_B  Type_of_Cab_C  ...  \
# Trip_Distance                  0.231706      -0.049238      -0.011554  ...
# Customer_Since_Months          0.110851      -0.002355       0.004740  ...
# Life_Style_Index               0.303324      -0.002509      -0.033352  ...
# Customer_Rating               -0.227531       0.027020      -0.031793  ...
# Cancellation_Last_1Month       0.128686      -0.051113       0.026167  ...
# Var1                          -0.020892       0.008309      -0.002987  ...
# Var2                           0.683437      -0.007217      -0.005590  ...
# Var3                           1.000000      -0.003357      -0.012346  ...
# Type_of_Cab_B                 -0.003357       1.000000      -0.416698  ...
# Type_of_Cab_C                 -0.012346      -0.416698       1.000000  ...
# Type_of_Cab_D                 -0.011142      -0.328262      -0.213962  ...
# Type_of_Cab_E                 -0.002894      -0.248929      -0.162253  ...
# Confidence_Life_Style_Index_B  0.066604      -0.032986       0.018347  ...
# Confidence_Life_Style_Index_C  0.008535      -0.016444       0.006601  ...
# Destination_Type_B             0.001765       0.042623      -0.008071  ...
# Destination_Type_C             0.014608      -0.004482      -0.000282  ...
# Destination_Type_D            -0.051876      -0.029513      -0.009448  ...
# Destination_Type_E            -0.036689      -0.004555      -0.013470  ...
# Destination_Type_F            -0.025378      -0.014112      -0.012504  ...
# Destination_Type_G            -0.034315      -0.000101      -0.006667  ...
# Destination_Type_H            -0.007976      -0.013176      -0.004402  ...
# Destination_Type_I            -0.025787      -0.011938      -0.006778  ...
# Destination_Type_J            -0.016411      -0.010108      -0.003695  ...
# Destination_Type_K            -0.028876      -0.000693      -0.010663  ...
# Destination_Type_L            -0.007760      -0.005531      -0.002483  ...
# Destination_Type_M            -0.004894      -0.002502      -0.003393  ...
# Destination_Type_N            -0.016493       0.001017       0.000726  ...
# Gender_Male                    0.003520      -0.000635      -0.001079  ...
#
#                                Destination_Type_F  Destination_Type_G  \
# Trip_Distance                            0.010783           -0.078761
# Customer_Since_Months                   -0.020596           -0.023704
# Life_Style_Index                         0.021958           -0.027208
# Customer_Rating                          0.055861            0.058156
# Cancellation_Last_1Month                 0.028450            0.004040
# Var1                                    -0.006899            0.003675
# Var2                                    -0.032692           -0.042712
# Var3                                    -0.025378           -0.034315
# Type_of_Cab_B                           -0.014112           -0.000101
# Type_of_Cab_C                           -0.012504           -0.006667
# Type_of_Cab_D                            0.013911           -0.007314
# Type_of_Cab_E                            0.022972           -0.012039
# Confidence_Life_Style_Index_B            0.033085           -0.021294
# Confidence_Life_Style_Index_C           -0.003485           -0.006248
# Destination_Type_B                      -0.065965           -0.057541
# Destination_Type_C                      -0.030100           -0.026256
# Destination_Type_D                      -0.028140           -0.024546
# Destination_Type_E                      -0.017798           -0.015525
# Destination_Type_F                       1.000000           -0.013113
# Destination_Type_G                      -0.013113            1.000000
# Destination_Type_H                      -0.012052           -0.010513
# Destination_Type_I                      -0.009665           -0.008430
# Destination_Type_J                      -0.008932           -0.007791
# Destination_Type_K                      -0.008834           -0.007706
# Destination_Type_L                      -0.008589           -0.007492
# Destination_Type_M                      -0.003260           -0.002843
# Destination_Type_N                      -0.003346           -0.002919
# Gender_Male                             -0.000517           -0.000308
#
#                                Destination_Type_H  Destination_Type_I  \
# Trip_Distance                           -0.065450           -0.067025
# Customer_Since_Months                   -0.005812           -0.038896
# Life_Style_Index                        -0.008661           -0.018124
# Customer_Rating                          0.012988            0.022421
# Cancellation_Last_1Month                 0.002679            0.007901
# Var1                                    -0.001149            0.000149
# Var2                                    -0.016374           -0.024090
# Var3                                    -0.007976           -0.025787
# Type_of_Cab_B                           -0.013176           -0.011938
# Type_of_Cab_C                           -0.004402           -0.006778
# Type_of_Cab_D                            0.013380            0.014276
# Type_of_Cab_E                            0.018873            0.015427
# Confidence_Life_Style_Index_B           -0.007583           -0.014761
# Confidence_Life_Style_Index_C           -0.006338           -0.002631
# Destination_Type_B                      -0.052885           -0.042408
# Destination_Type_C                      -0.024132           -0.019351
# Destination_Type_D                      -0.022560           -0.018091
# Destination_Type_E                      -0.014269           -0.011442
# Destination_Type_F                      -0.012052           -0.009665
# Destination_Type_G                      -0.010513           -0.008430
# Destination_Type_H                       1.000000           -0.007748
# Destination_Type_I                      -0.007748            1.000000
# Destination_Type_J                      -0.007161           -0.005742
# Destination_Type_K                      -0.007083           -0.005679
# Destination_Type_L                      -0.006886           -0.005522
# Destination_Type_M                      -0.002613           -0.002096
# Destination_Type_N                      -0.002683           -0.002151
# Gender_Male                             -0.000969           -0.005750
#
#                                Destination_Type_J  Destination_Type_K  \
# Trip_Distance                           -0.070772           -0.032169
# Customer_Since_Months                    0.001861           -0.033298
# Life_Style_Index                        -0.015995           -0.006097
# Customer_Rating                          0.012134            0.027700
# Cancellation_Last_1Month                 0.002417            0.011404
# Var1                                     0.003012            0.002711
# Var2                                    -0.020074           -0.017317
# Var3                                    -0.016411           -0.028876
# Type_of_Cab_B                           -0.010108           -0.000693
# Type_of_Cab_C                           -0.003695           -0.010663
# Type_of_Cab_D                            0.010070            0.003594
# Type_of_Cab_E                            0.010558            0.003328
# Confidence_Life_Style_Index_B           -0.007700           -0.003128
# Confidence_Life_Style_Index_C           -0.006788           -0.009930
# Destination_Type_B                      -0.039192           -0.038765
# Destination_Type_C                      -0.017884           -0.017689
# Destination_Type_D                      -0.016719           -0.016536
# Destination_Type_E                      -0.010574           -0.010459
# Destination_Type_F                      -0.008932           -0.008834
# Destination_Type_G                      -0.007791           -0.007706
# Destination_Type_H                      -0.007161           -0.007083
# Destination_Type_I                      -0.005742           -0.005679
# Destination_Type_J                       1.000000           -0.005249
# Destination_Type_K                      -0.005249            1.000000
# Destination_Type_L                      -0.005103           -0.005048
# Destination_Type_M                      -0.001937           -0.001916
# Destination_Type_N                      -0.001988           -0.001966
# Gender_Male                             -0.001082           -0.000696
#
#                                Destination_Type_L  Destination_Type_M  \
# Trip_Distance                            0.006428           -0.009844
# Customer_Since_Months                   -0.011319            0.001978
# Life_Style_Index                         0.003144            0.008153
# Customer_Rating                          0.033101            0.010281
# Cancellation_Last_1Month                 0.037134            0.003636
# Var1                                     0.002638            0.000995
# Var2                                    -0.015042           -0.002572
# Var3                                    -0.007760           -0.004894
# Type_of_Cab_B                           -0.005531           -0.002502
# Type_of_Cab_C                           -0.002483           -0.003393
# Type_of_Cab_D                           -0.002402            0.002918
# Type_of_Cab_E                            0.007364            0.001795
# Confidence_Life_Style_Index_B            0.002689           -0.002162
# Confidence_Life_Style_Index_C            0.003019            0.004872
# Destination_Type_B                      -0.037690           -0.014304
# Destination_Type_C                      -0.017198           -0.006527
# Destination_Type_D                      -0.016078           -0.006102
# Destination_Type_E                      -0.010169           -0.003859
# Destination_Type_F                      -0.008589           -0.003260
# Destination_Type_G                      -0.007492           -0.002843
# Destination_Type_H                      -0.006886           -0.002613
# Destination_Type_I                      -0.005522           -0.002096
# Destination_Type_J                      -0.005103           -0.001937
# Destination_Type_K                      -0.005048           -0.001916
# Destination_Type_L                       1.000000           -0.001863
# Destination_Type_M                      -0.001863            1.000000
# Destination_Type_N                      -0.001912           -0.000726
# Gender_Male                             -0.001585           -0.002103
#
#                                Destination_Type_N  Gender_Male
# Trip_Distance                           -0.027335     0.002173
# Customer_Since_Months                   -0.021416     0.001326
# Life_Style_Index                        -0.026124     0.000626
# Customer_Rating                          0.018762     0.000468
# Cancellation_Last_1Month                 0.004370     0.002307
# Var1                                    -0.005564     0.000619
# Var2                                    -0.011555     0.003183
# Var3                                    -0.016493     0.003520
# Type_of_Cab_B                            0.001017    -0.000635
# Type_of_Cab_C                            0.000726    -0.001079
# Type_of_Cab_D                           -0.008034     0.001043
# Type_of_Cab_E                           -0.004572     0.001228
# Confidence_Life_Style_Index_B           -0.010096     0.002857
# Confidence_Life_Style_Index_C           -0.010482     0.002627
# Destination_Type_B                      -0.014684    -0.002267
# Destination_Type_C                      -0.006700     0.005257
# Destination_Type_D                      -0.006264    -0.000577
# Destination_Type_E                      -0.003962     0.001921
# Destination_Type_F                      -0.003346    -0.000517
# Destination_Type_G                      -0.002919    -0.000308
# Destination_Type_H                      -0.002683    -0.000969
# Destination_Type_I                      -0.002151    -0.005750
# Destination_Type_J                      -0.001988    -0.001082
# Destination_Type_K                      -0.001966    -0.000696
# Destination_Type_L                      -0.001912    -0.001585
# Destination_Type_M                      -0.000726    -0.002103
# Destination_Type_N                       1.000000    -0.000550
# Gender_Male                             -0.000550     1.000000
#
# [28 rows x 28 columns]

# %% [markdown]
# **Задание 4.** Обучите логистическую регрессию на первых двух компонентах центрированных данных и подберите гиперпараметры. Обучите логистическую регрессию на центрированных данных и подберите гиперпараметры. **Сравните метрику accuracy и f1-score на тестовой выборке в двух моделях**.
#
# P.S. для удобства, скорости и нормализации данных (понадобится, так как захотим повалидироваться на параметрах регуляризации) можно построить конструкцию Pipeline c 3 следующими степами: StandardScaler -> PCA -> LogisticRegression

# %%
np.random.seed(2022)
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X_centered, y, test_size=0.2, 
                                                    shuffle=True, random_state=2022)

# %%
### Your code is here

param_grid = {'model__penalty': ['l1', 'l2', 'elasticnet'],
              'model__C': [1e-5, 0.0001, 0.001, 0.01]}


pipe_1 = Pipeline(
    [
        ('scaler', StandardScaler()), 
        ('PCA', PCA(n_components=2)), 
        ('model', LogisticRegression())
    ]
)

# %%
grid = GridSearchCV(pipe_1, param_grid)
grid.fit(X_train, y_train)
y_pred = grid.predict(X_test)
print(classification_report(y_test, y_pred, digits = 3))
# Out:
#               precision    recall  f1-score   support
#
#            1      0.000     0.000     0.000      5372
#            2      0.477     0.696     0.567     11349
#            3      0.495     0.503     0.499      9612
#
#     accuracy                          0.484     26333
#    macro avg      0.324     0.400     0.355     26333
# weighted avg      0.386     0.484     0.426     26333

# %%
pipe_2 = Pipeline([('scaler', StandardScaler()), ('model', LogisticRegression())])
grid_2 = GridSearchCV(pipe_2, param_grid)
grid_2.fit(X_train, y_train)
y_pred = grid_2.predict(X_test)
print(classification_report(y_test, y_pred, digits = 3))
# Out:
#               precision    recall  f1-score   support
#
#            1      0.746     0.532     0.621      5372
#            2      0.636     0.830     0.720     11349
#            3      0.736     0.589     0.655      9612
#
#     accuracy                          0.681     26333
#    macro avg      0.706     0.650     0.665     26333
# weighted avg      0.695     0.681     0.676     26333

# %% [markdown]
# Кажется, достаточно сильно теряем в качестве! Может, добавить компонент?

# %% [markdown]
# **Задание 5.** Обучите модели логистической регресии на нескольких различных компонентах: [2, 4, 8, 16, 28]. **Нарисуйте графики зависимости accuracy, f1-score от количества компонент. Введите их значения через запятую**. При обучении используйте l2-регуляризацию, гиперпараметр C подбирайте по сетке.

# %%
### Чтобы не заставлять вас писать похожий на предыдущий код,
### Написали функцию, которая будет обучать модель для
### произвольного числа n_components главных компонент.

def train_pca_i(n_components, X_train, y_train):
    pipe = Pipeline([('scaler', StandardScaler()), 
                     ('pca', PCA(n_components=n_components)),
                     ('model', LogisticRegression(penalty='l2', solver='saga',random_state=1))])
    
    param_grid = {'model__C': [0.0001, 0.001, 0.01, 0.1]}
    
    grid = GridSearchCV(pipe, param_grid, cv=5)
    grid.fit(X_train, y_train)
    
    report = classification_report(y_test, grid.predict(X_test), output_dict=True)
    return (report['accuracy'], 
            report['weighted avg']['f1-score'])

# %%
# %%time
accuracy_dict, f1_score_dict = {}, {}
components_list = [2, 4, 8, 16, 28]

accs = []
scores = []

for n_components in components_list:
    
    ### Your code is here
    res = train_pca_i(n_components, X_train, y_train)
    accs.append(res[0])
    scores.append(res[1])
# Out:
# CPU times: user 2min 13s, sys: 44.3 s, total: 2min 57s
# Wall time: 49.9 s

# %%
scores
# Out:
# [0.42539601180945336,
#  0.47373121331460993,
#  0.5201254610241981,
#  0.5274627898778056,
#  0.6760757307801638]

# %% [markdown]
# Обычно, когда решается какая-то высокоразмерная предсказательная задача, где тысячи признаков, функция качества PCA моделей похожа на параболу ветвями вниз в зависимости от количества компонент (для совсем маленьких и больших n_component качество маленькое, при этом есть где-то промежуточное значение).
#
# Как думаете, почему здесь у нас непрерывно растущие графики качества?
#
# Может, изначальные признаки были слишком хороши?

# %% [markdown]
# ### t-SNE
#
# Напомним, что метод заключается в введении некоторых функций, основанных на расстоянии между признаками, которые измеряют близость объектов. Функций, как вы помните, две, и они заданы в исходном и новом пространствах соотвественно. Далее минимизируем дивергенцию Кульбака-Лейблера по координатaм в новом пространстве

# %% [markdown]
# **Задание 6.** Обучите t-sne c `n_components=2` на изначальных данных и визуализируйте результаты с учетом известных классов.

# %% [markdown]
# P.S. если устанете ждать обучения TSNE, или упадет ошибка по типу oom, то можно сократить число объектов в датасете до, например, пары тысяч. Это и следующее задания никак проверяться системой не будут. Вам достаточно повторить упражнение с практики и получить какое-то более адекватное (по сравнению с PCA) изображение классов.

# %%
from sklearn.manifold import TSNE

### Your code is here

# %% [markdown]
# **Задание 7.** Обучите t-sne с `n_components=3` на изначальных данных и визуализируйте результаты с учетом известных классов.

# %%
### Your code is here

# %% [markdown]
# Советуем обрезать датасет до маленького числа объектов (чтобы точки и их группки были хорошо различимы) и поиграться с гиперпараметрами класса Tsne! Обычно такая "игра" может привести к куда более красивым результатам по сравнению с теми, что получены с дефолтными настройками!
